# %% [markdown]
# # Inference: Anemonefish Target to noise classifier
#
# This notebook implements a prediction module that processes audio files to detect anemonefish calls using the trained classifier. The module applies the exact same preprocessing pipeline as training and uses a sliding window approach for temporal analysis.
#
# ## Pipeline Overview:
# 1. Input: Audio file
# 2. Output: Audacity labels
#
# Pipeline:
# 1.
#
#
# 3. **Audio Loading & Preprocessing** - Load and normalize audio consistently with training
# 4. **Sliding Window Analysis** - Extract 1-second windows with overlap for high temporal resolution
# 5. **Spectrogram Generation** - Create spectrograms with identical parameters as training
# 6. **Model Prediction** - Apply trained classifier to each window
# 7. **Post-Processing** - Smooth predictions and detect events
# 8. **Results Export** - Generate timestamps and confidence scores
